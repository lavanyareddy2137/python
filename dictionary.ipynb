# %%
employees = {
    "Ravi": 50000,
    "Priya": 60000,
    "Amit": 55000
}
name = input("Enter employee name: ")
if name in employees:
    print("Salary:", employees[name])
else:
    print("Employee not found")
# Out:
# Enter employee name:  Priya
# Salary: 60000

# %%
fruits = {
    "Apple": 120,
    "Banana": 40,
    "Orange": 80,
    "Mango": 150,
    "Grapes": 90
}
print("Fruit Dictionary:", fruits)
# Out:
# Fruit Dictionary: {'Apple': 120, 'Banana': 40, 'Orange': 80, 'Mango': 150, 'Grapes': 90}

# %%
employees = {
    "Ravi": 50000,
    "Priya": 60000,
    "Amit": 55000
}
name = input("Enter employee name: ")
if name in employees:
    print("Salary:", employees[name])
else:
    print("Employee not found")
# Out:
# Enter employee name:  Ravi
# Salary: 50000

# %%
countries = {
    "India": "New Delhi",
    "USA": "Washington D.C.",
    "Japan": "Tokyo",
    "France": "Paris"
}
print("Countries and Capitals:")
for country, capital in countries.items():
    print(country, ":", capital)
# Out:
# Countries and Capitals:
# India : New Delhi
# USA : Washington D.C.
# Japan : Tokyo
# France : Paris

# %%
student = {
    "name": "Rahul",
    "marks": 75
}
new_marks = float(input("Enter new marks: "))
student["marks"] = new_marks

print("Updated Dictionary:", student)
# Out:
# Enter new marks:  20
# Updated Dictionary: {'name': 'Rahul', 'marks': 20.0}

# %%
inventory = {
    "Laptop": 10,
    "Mouse": 25,
    "Keyboard": 15
}
product = input("Enter product name: ")
amount = int(input("Enter quantity to add: "))
if product in inventory:
    inventory[product] += amount
    print("Updated Inventory:", inventory)
else:
    print("Product not found")
# Out:
# Enter product name:  Laptop
# Enter quantity to add:  20
# Updated Inventory: {'Laptop': 30, 'Mouse': 25, 'Keyboard': 15}

# %%
student = {
    "name": "Rahul",
    "marks": 85,
    "age": 20
}
key = input("Enter key to delete: ")
if key in student:
    del student[key]
    print("Updated Dictionary:", student)
else:
    print("Key not found")
