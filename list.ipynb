# %%
my_list = []

for i in range(5):
    element = input(f"Enter element {i + 1}: ")
    my_list.append(element)

print("List:", my_list)
# Out:
# Enter element 1:  1
# Enter element 2:  2
# Enter element 3:  3
# Enter element 4:  4
# Enter element 5:  5
# List: ['1', '2', '3', '4', '5']

# %%
my_list = [10, 20, 30, 40, 50]

print("Elements of the list:")
for element in my_list:
    print(element)
# Out:
# Elements of the list:
# 10
# 20
# 30
# 40
# 50

# %%
my_list = [10, 20, 30, 40, 50]

element = input("Enter element to add at the end: ")
my_list.append(element)

print("Updated List:", my_list)
# Out:
# Enter element to add at the end:  7
# Updated List: [10, 20, 30, 40, 50, '7']

# %%
my_list = [10, 20, 30, 40, 50]

index = int(input("Enter index: "))
element = input("Enter element to insert: ")

my_list.insert(index, element)

print("Updated List:", my_list)
# Out:
# Enter index:  0
# Enter element to insert:  70
# Updated List: ['70', 10, 20, 30, 40, 50]

# %%
my_list = [10, 20, 30, 40, 50]

index = int(input("Enter index to remove: "))

if 0 <= index < len(my_list):
    my_list.pop(index)

if len(my_list) > 0:
    my_list.pop(0)  # Remove first element

if len(my_list) > 0:
    my_list.pop(-1)  # Remove last element

print("Updated List:", my_list)
# Out:
# Enter index to remove:  4
# Updated List: [20, 30]

# %%
my_list = [10, 20, 30, 40, 50]

element = int(input("Enter element to remove: "))

if element in my_list:
    my_list.remove(element)
    print("Updated List:", my_list)
else:
    print("Element not found in the list.")
# Out:
# Enter element to remove:  30
# Updated List: [10, 20, 40, 50]

# %%
my_list = [10, 20, 30, 40, 50]

del my_list

print("List deleted."
